# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg'
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 25.5MB/s]
# image 1/1 /content/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 93.9ms
# Speed: 13.2ms preprocess, 93.9ms inference, 602.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Custom Data Train

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=../content/drive/MyDrive/TrainModel/ConstructionSiteSafety/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
